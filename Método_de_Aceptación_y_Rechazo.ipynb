# %% [markdown]
# <a href="https://colab.research.google.com/github/MartaPCastillo/Simulacion-I/blob/main/M%C3%A9todo_de_Aceptaci%C3%B3n_y_Rechazo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Método de Aceptación y Rechazo

# %% [markdown]
# Para mostrar este método ocuparemos la función $f(x) = \dfrac{e^x}{e - 1}$, $0 \leq x \leq 1$.

# %% [markdown]
# ###Analíticamente

# %% [markdown]
# 1. Comprobamos que $f(x)$ es fdp.
#
# •$f(x) \geq 0$
#
# •$\int_{-\infty}^{\infty} f(x) \,dx = 1$

# %% [markdown]
# 2. Luego, graficamos y escogemos que $c = \dfrac{e}{e-1}$

# %% [markdown]
# De tal forma que nos queda $g(x) \sim U(0,1) \longrightarrow g(x) = 1$

# %% [markdown]
# Sabemos que
#
# $\dfrac{f(x)}{g(x)} \leq c$ o escrito de otra forma $\dfrac{f(x)}{c} \leq g(x)$
#
# $f(x) \leq \dfrac{e}{e-1}$, si $0 \leq x \leq 1$

# %% [markdown]
# ###Simulación

# %% [markdown]
# 1. Generar $Y \sim U(0,1)$
# 2. Generar $U \sim U(0,1)$
# 3. Si $U \leq \dfrac{f(y)}{c g(y)}$, hacemos $X = Y$
# 4. Caso contrario, regresar al paso 1

# %%
import random                                   # importamos el módulo random
import numpy as np                              # importamos numpy con un alias (np)
import matplotlib.pyplot as plt                 # ídem
#from random import expovariate, gauss
from statistics import mean, median, variance, stdev      # exportamos funciones especificas de statistic

# %%
def met_acep_rech(n):
    lista = []
    for i in range(n):
      Y = random.random()
      U = random.random()
      f_y = (np.exp^Y)/(np.exp - 1)
      g_y =
      if 0 <= R_1 <= m:
         X= a + (c-a)*(np.sqrt(R_2))
      else:
         X= c - (c-b)*(np.sqrt(R_2))
      lista.append(X)
    return lista

# %%
G=met_comp(2,5,8,1000)
print(G)
# Out:
# [6.100636903627114, 6.5802132502262864, 7.266149921243195, 7.670430220927313, 7.024730097077873, 5.900442317141327, 6.887240941872421, 5.930724205909151, 6.4833384060696595, 6.436670395302609, 7.46150447759818, 5.65064461078086, 7.056507840914291, 7.383603509383229, 4.023246891675672, 7.57633240824481, 6.569350157565703, 7.375580816936374, 5.297546542634, 2.7758497630762378, 5.441387237507493, 6.663672222270308, 7.749564372812459, 5.68443534724201, 6.001121437299418, 5.403794936289704, 5.794789200937332, 5.72351820665855, 5.606772960256745, 3.2642745807417253, 5.92030554160209, 6.446092226033161, 6.245606697464946, 7.254160169533224, 5.141367887456173, 5.866547844044234, 6.016737447391869, 4.582084897215228, 5.368445410862151, 5.997566544710441, 6.3045713892513815, 5.7976963441173925, 5.210565874102696, 3.868490398540753, 5.813167509366427, 3.7448611389752413, 5.6222187611876855, 7.76103052435837, 4.4255336601665025, 6.9477973842411345, 7.574651613710612, 6.398651534410514, 6.9097869
# ...

# %%
mu=np.mean(G)
print(mu)
# Out:
# 6.056955437433854

# %%
sigma2=np.var(G)
print(sigma2)
# Out:
# 1.0448547446095764

# %%
plt.hist(G, bins=50)
plt.show()

# %%
plt.plot(G)
plt.show()

# %%
def cdf(muestra):
  m=len(muestra)
  x=np.sort(muestra)
  y=np.arange(0,m)/m
  return x,y

# %%
X,Y = cdf(G)

# %%
plt.step(X,Y)
plt.show()
