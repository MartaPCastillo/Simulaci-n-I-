# %% [markdown]
# <a href="https://colab.research.google.com/github/MartaPCastillo/Simulacion-I/blob/main/M%C3%A9todo_de_Aceptaci%C3%B3n_y_Rechazo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Método de Aceptación y Rechazo

# %% [markdown]
# Para mostrar este método ocuparemos la función $f(x) = \dfrac{e^x}{e - 1}$, $0 \leq x \leq 1$.

# %% [markdown]
# ###Analíticamente

# %% [markdown]
# 1. Comprobamos que $f(x)$ es fdp.
#
# •$f(x) \geq 0$
#
# •$\int_{-\infty}^{\infty} f(x) \,dx = 1$

# %% [markdown]
# 2. Luego, graficamos y escogemos que $c = \dfrac{e}{e-1}$

# %% [markdown]
# De tal forma que nos queda $g(x) \sim U(0,1) \longrightarrow g(x) = 1$

# %% [markdown]
# Sabemos que
#
# $\dfrac{f(x)}{g(x)} \leq c$ o escrito de otra forma $\dfrac{f(x)}{c} \leq g(x)$
#
# $f(x) \leq \dfrac{e}{e-1}$, si $0 \leq x \leq 1$

# %% [markdown]
# ###Simulación

# %% [markdown]
# 1. Generar $Y \sim U(0,1)$
# 2. Generar $U \sim U(0,1)$
# 3. Si $U \leq \dfrac{f(y)}{c g(y)}$, hacemos $X = Y$
# 4. Caso contrario, regresar al paso 1

# %%
import random                                   # importamos el módulo random
import numpy as np                              # importamos numpy con un alias (np)
import matplotlib.pyplot as plt                 # ídem
#from random import expovariate, gauss
from statistics import mean, median, variance, stdev      # exportamos funciones especificas de statistic

# %%
def met_acep_rech(n):
    lista = []
    g_y = 1
    c = (np.exp(1)) / (np.exp(1) - 1)
    for i in range(n):
      Y = random.random()
      U = random.random()
      f_y = (np.exp(Y))/(np.exp(1) - 1)
      X = 0
      if U <= (f_y)/(c * g_y):
         X = Y
      lista.append(X)
    return lista

# %%
G=met_acep_rech(1000)
print(G)
# Out:
# [0.4718571110333809, 0.9377416714060551, 0.8881486589691086, 0.3694695832658097, 0.782529596589021, 0.2830049340184272, 0, 0.44179545440173806, 0, 0, 0.7258349228393715, 0.3073027516738196, 0, 0.6039670882252964, 0.9323068161870748, 0, 0.3400741732344774, 0, 0.8122839695451034, 0.4227601896604011, 0.17771214408064262, 0, 0, 0, 0, 0, 0.6808535059257104, 0, 0.5986873718659403, 0, 0.951297482050953, 0.46952730580629076, 0, 0, 0.19565210967956126, 0, 0.3352042448616146, 0.32370289978917144, 0.9879989059470142, 0, 0.8311266935542898, 0.26580266481419057, 0, 0, 0.8789710558199298, 0, 0, 0, 0, 0.5092869519347213, 0.03386260881831449, 0.5737641836379114, 0.5264502391828506, 0, 0.15584916200959475, 0, 0.4715422343537785, 0, 0, 0.4668936420462092, 0.48601772748564176, 0.1894677817067275, 0.5035140633310867, 0.3908174763054818, 0, 0.9949828993915967, 0, 0, 0.4622432154532069, 0.0016935232068502337, 0.9917396641950142, 0.4185978783095692, 0.26578795062005767, 0.6796496717562777, 0, 0.22144036287339974, 0, 0.08332432612681728, 0.49533816474986225, 0.549539041589071, 0, 0.43061027138141283, 0.8998607523542052, 0.9500050978630816, 0.8328957343156904, 0.7190549413458517, 0, 0.2603136643926647, 0, 0, 0.3678391247680818, 0, 0.9014353213965106, 0.9631858388369857, 0.2739949601259538, 0, 0, 0.5162623887645035, 0.9315255885969228, 0, 0.5842231181043126, 0.5994501155446105, 0.6904405339659482, 0.39093535726458417, 0.4191105821807708, 0, 0.40405875245075207, 0.7794364310925666, 0.062107969903336446, 0.20983633613364494, 0.8932812357371149, 0.06734234228171432, 0.9738566437976555, 0.7354887576101742, 0, 0, 0.4788626866497673, 0.5483635965232918, 0, 0.8259527225806537, 0, 0.47117663404474264, 0, 0.6643079788056612, 0, 0.03310926555146754, 0.42698778321751774, 0.5949517212793615, 0.6748587294608918, 0.5991924432757447, 0.7174196087336159, 0, 0.24293255294546046, 0.7973673009974286, 0, 0, 0, 0.44371830806059775, 0.22942689200568467, 0.7090659120819068, 0, 0.8993568548741303, 0, 0.17085021413244406, 0.27903061349807257, 0, 0, 0, 0.16430756363458565, 0.4511870454397727, 0.18001653804987083, 0.6111400681219291, 0.9171210910526095, 0.8691548427598642, 0.9429884101255872, 0.7942269953266355, 0.926037221299171, 0.5469579602588514, 0, 0.428165103137921, 0.27002409117900517, 0.3457179897833985, 0.9923487841916488, 0.4664688303852851, 0.6572280133719415, 0.10332797527142812, 0.8691845216866969, 0.9390031114568089, 0.9536639802576276, 0.9530157782597375, 0.8512693082527782, 0, 0, 0.9886839325567145, 0.9299842092295508, 0.44027418370320837, 0.6539318764818848, 0, 0.7350675497777397, 0, 0, 0.9155859455900518, 0, 0, 0.6860047163481244, 0, 0, 0, 0.8347162152412582, 0, 0, 0, 0.9769643109929402, 0.527098977555294, 0.24850368037439707, 0.11591697725306016, 0, 0.19098714703413522, 0.8031631569366872, 0.8019043272987301, 0.737301253976485, 0.8246326989405556, 0.7138760447123946, 0.36133321624732617, 0.13269528762886673, 0.028544299057590594, 0, 0.28081977886936915, 0, 0.20354093946072582, 0.23096564645426243, 0, 0.4077159186517968, 0, 0, 0.6272383712981389, 0.424839098400997, 0, 0.9905360328233286, 0, 0, 0.5512086016545872, 0.5278124525460774, 0.7922761135906823, 0.5566369048089189, 0, 0.38912712930497095, 0.4362256967738142, 0.8870439140257236, 0.7437774383553909, 0.4118871992650498, 0.4204811859244886, 0.9029893676362704, 0, 0, 0.438561650723612, 0.6176193332037325, 0.8413683161796636, 0.8678790461772667, 0.8998459035710392, 0.008643983837076319, 0, 0.9529012077873067, 0, 0.6752406587067363, 0.40219897814504435, 0.8250976654295652, 0.4039761536125285, 0.7638252572357377, 0.6473236384730991, 0, 0.8309411235479627, 0, 0.17048357008353088, 0, 0.6450667460300779, 0.9690435375120888, 0.5036537072588039, 0.896555005885819, 0.7339406363292337, 0.8960445016871833, 0, 0.12400960367708436, 0.8420599618942518, 0.9520640341149955, 0.5869319700725419, 0, 0.2525500159095232, 0, 0, 0.4631646932608746, 0, 0.9629799485592238, 0.18330009623734467, 0.05724863839837402, 0.1149073594373301, ...

# %%
mu=np.mean(G)
print(mu)
# Out:
# 0.36332965350553764

# %%
sigma2=np.var(G)
print(sigma2)
# Out:
# 0.1253897007588702

# %%
plt.hist(G, bins=50)
plt.show()

# %%
plt.plot(G)
plt.show()

# %%
def cdf(muestra):
  m=len(muestra)
  x=np.sort(muestra)
  y=np.arange(0,m)/m
  return x,y

# %%
X,Y = cdf(G)

# %%
plt.step(X,Y)
plt.show()
